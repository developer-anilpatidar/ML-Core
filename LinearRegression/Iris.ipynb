# %%
from sklearn.datasets import load_iris
import pandas as pd

# %%
iris = load_iris()

# %%
#Key                    Description
#iris.data              The actual features (sepal/petal measurements)
#iris.feature_names.    Names of those features (column names)
#iris.target            The species (0, 1, or 2) as numbers
#iris.target_names      The actual species names (['setosa', 'versicolor', 'virginica']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
# Add the species column (target)
df['species'] = iris.target
df['species'] = df['species'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Filter data where sepal width grather than 4
df[df['sepal width (cm)'] > 4]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 15                5.7               4.4                1.5               0.4
# 32                5.2               4.1                1.5               0.1
# 33                5.5               4.2                1.4               0.2
#
#    species
# 15  setosa
# 32  setosa
# 33  setosa

# %%
# Filter data where petal width grather than 1
df[df['petal width (cm)'] > 1]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                 7.0               3.2                4.7               1.4
# 51                 6.4               3.2                4.5               1.5
# 52                 6.9               3.1                4.9               1.5
# 53                 5.5               2.3                4.0               1.3
# 54                 6.5               2.8                4.6               1.5
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#         species
# ...

# %%
# Filter data where petal width grather than 2
df[df['petal width (cm)'] > 2]
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 102                7.1               3.0                5.9               2.1
# 104                6.5               3.0                5.8               2.2
# 105                7.6               3.0                6.6               2.1
# 109                7.2               3.6                6.1               2.5
# 112                6.8               3.0                5.5               2.1
# 114                5.8               2.8                5.1               2.4
# 115                6.4               3.2                5.3               2.3
# 117                7.7               3.8                6.7               2.2
# 118                7.7               2.6                6.9               2.3
# 120                6.9               3.2                5.7               2.3
# ...

# %% [markdown]
# ___

# %% [markdown]
# # Data Visulaization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='sepal length (cm)', y='petal length (cm)', data=df, hue='species')
# Out:
# <Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>

# %% [markdown]
# ___

# %% [markdown]
# # Linear Regression

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# rename the dataframe cloumn
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Now we need to devide data in tranning and testing sets using sklearn train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['sepal_length']]
y = df[['sepal_width']]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.9)

# %%
x_train.head()
# Out:
#      sepal_length
# 134           6.1
# 36            5.5
# 17            5.1
# 43            5.0
# 107           7.3

# %%
x_test.head()
# Out:
#      sepal_length
# 42            4.4
# 112           6.8
# 53            5.5
# 147           6.5
# 81            5.5

# %%
y_train.head()
# Out:
#      sepal_width
# 134          2.6
# 36           3.5
# 17           3.5
# 43           3.5
# 107          2.9

# %%
y_test.head()
# Out:
#      sepal_width
# 42           3.2
# 112          3.0
# 53           2.3
# 147          3.0
# 81           2.4

# %% [markdown]
# # Apply Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

lr_model = LinearRegression()

# %%
# Fit data for traning purpose using fit method
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(x_test)

# %%
y_test.head()
# Out:
#      sepal_width
# 42           3.2
# 112          3.0
# 53           2.3
# 147          3.0
# 81           2.4

# %%
y_predict[0:5]
# Out:
# array([[3.46872038],
#        [2.84312796],
#        [3.18199052],
#        [2.92132701],
#        [3.18199052]])

# %% [markdown]
# ___

# %% [markdown]
# # Error in prediction

# %%
from sklearn.metrics import mean_squared_error

# %%
# mean_squared_error(actual_values, predicted_values)
mean_squared_error(y_test, y_pred)
# Out:
# 0.2252349577852149

# %% [markdown]
# ___

# %% [markdown]
# # model 2

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y = df['sepal_length']
x = df[['sepal_width','petal_length','petal_width']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.9)

# %%
lr_model2 = LinearRegression()

# %%
lr_model2.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model2.predict(x_test)

# %%
y_pred[0:5]
# Out:
# array([7.03013151, 4.66708419, 6.79099804, 4.75059336, 7.26909592])

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.10495627437344353

# %% [markdown]
# Mean square error of 2nd nodel is less than first model so 2nd model is better than first model
